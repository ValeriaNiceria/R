# %% [markdown]
# ## ggplot2

# %%
library(tidyverse)
# Pacote janitor para limpar os nomes das colunas
library(janitor)
# Metadados gerais de países
library(countrycode)
# Combinar vários gráficos do ggplot2 em um só
library(patchwork) # devtools::install_github("thomasp85/patchwork")
# Checando a versão dos pacotes
sessionInfo()
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.2.1     v purrr   0.3.2
# v tibble  2.1.3     v dplyr   0.8.2
# v tidyr   0.8.3     v stringr 1.4.0
# v readr   1.3.1     v forcats 0.4.0
# Warning message:
# "package 'ggplot2' was built under R version 3.6.1"Warning message:
# "package 'tibble' was built under R version 3.6.1"Warning message:
# "package 'tidyr' was built under R version 3.6.1"Warning message:
# "package 'readr' was built under R version 3.6.1"Warning message:
# "package 'stringr' was built under R version 3.6.1"-- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# Warning message:
# "package 'janitor' was built under R version 3.6.1"
# Attaching package: 'janitor'
#
# The following objects are masked from 'package:stats':
#
#     chisq.test, fisher.test
#
# Warning message:
# "package 'countrycode' was built under R version 3.6.1"
# R version 3.6.0 (2019-04-26)
# Platform: i386-w64-mingw32/i386 (32-bit)
# Running under: Windows 10 (build 18362)
#
# Matrix products: default
#
# locale:
# [1] LC_COLLATE=Portuguese_Brazil.1252  LC_CTYPE=Portuguese_Brazil.1252
# [3] LC_MONETARY=Portuguese_Brazil.1252 LC_NUMERIC=C
# [5] LC_TIME=Portuguese_Brazil.1252
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] patchwork_0.0.1   countrycode_1.1.0 janitor_1.2.0     forcats_0.4.0
#  [5] stringr_1.4.0     dplyr_0.8.2       purrr_0.3.2       readr_1.3.1
#  [9] tidyr_0.8.3       tibble_2.1.3      ggplot2_3.2.1     tidyverse_1.2.1
#
# loaded via a namespace (and not attached):
#  [1] withr_2.1.2      repr_0.19.2      rvest_0.3.4      tidyselect_0.2.5
#  [5] lattice_0.20-38  pkgconfig_2.0.2  pbdZMQ_0.3-3     xml2_1.2.0
#  [9] compiler_3.6.0   readxl_1.3.1     IRkernel_0.8.15  Rcpp_1.0.2
# [13] cli_1.1.0        cellranger_1.1.0 httr_1.4.0       tools_3.6.0
# [17] uuid_0.1-2       nlme_3.1-139     broom_0.5.2      R6_2.4.0
# [21] scales_1.0.0     assertthat_0.2.1 digest_0.6.20    gtable_0.3.0
# [25] evaluate_0.14    rstudioapi_0.10  stringi_1.4.3    backports_1.1.4
# [29] htmltools_0.3.6  hms_0.4.2        munsell_0.5.0    grid_3.6.0
# [33] colorspace_1.4-1 glue_1.3.1       lubridate_1.7.4  rlang_0.4.0
# [37] magrittr_1.5     generics_0.0.2   lazyeval_0.2.2   crayon_1.3.4
# [41] haven_2.1.0      IRdisplay_0.7.0  modelr_0.1.4     pillar_1.4.2
# [45] base64enc_0.1-3  jsonlite_1.6

# %%
# importar a planilha
df_pais <-  read.csv('felicidade.csv')
# limpar o nome das colunas
df_pais <- janitor::clean_names(df_pais)
# olhar dados 
glimpse(df_pais)
# Out:
# Observations: 1,562
# Variables: 19
# $ country                                                 <fct> Afghanistan...
# $ year                                                    <int> 2008, 2009,...
# $ life_ladder                                             <dbl> 3.723590, 4...
# $ log_gdp_per_capita                                      <dbl> 7.168690, 7...
# $ social_support                                          <dbl> 0.4506623, ...
# $ healthy_life_expectancy_at_birth                        <dbl> 49.20966, 4...
# $ freedom_to_make_life_choices                            <dbl> 0.7181143, ...
# $ generosity                                              <dbl> 0.18181947,...
# $ perceptions_of_corruption                               <dbl> 0.8816863, ...
# $ positive_affect                                         <dbl> 0.5176372, ...
# $ negative_affect                                         <dbl> 0.2581955, ...
# $ confidence_in_national_government                       <dbl> 0.6120721, ...
# $ democratic_quality                                      <dbl> -1.92968953...
# $ delivery_quality                                        <dbl> -1.6550844,...
# $ standard_deviation_of_ladder_by_country_year            <dbl> 1.774662, 1...
# $ standard_deviation_mean_of_ladder_by_country_year       <dbl> 0.4765997, ...
# $ gini_index_world_bank_estimate                          <dbl> NA, NA, NA,...
# $ gini_index_world_bank_estimate_average_2000_15          <dbl> NA, NA, NA,...
# $ gini_of_household_income_reported_in_gallup_by_wp5_year <dbl> NA, 0.44190...

# %%
df_continente <- countrycode::codelist %>% 
  # selecionar colunas importantes
  select(country = cow.name, continent) %>% 
  # filtrar fora os países sem continentes 
  filter(!is.na(continent))

# %%
df_pais$country <- as.character(df_pais$country)

# %%
# criar dataframe com junção dos dois
df <- left_join(df_pais,
                df_continente,
                by = "country")

# %%
# consertar manualmente os continentes de certos países
df$continent[df$country == "Congo (Brazzaville)"] <- "Africa"
df$continent[df$country == "Congo (Kinshasa)"] <- "Africa"
df$continent[df$country == "Hong Kong S.A.R of China"] <- "Asia"
df$continent[df$country == "Kosovo"] <- "Europe"
df$continent[df$country == "North Cyprus"] <- "Asia"
df$continent[df$country == "Palestinian Territories"] <- "Asia"
df$continent[df$country == "Serbia"] <- "Europe"
df$continent[df$country == "Somaliland region"] <- "Africa"
df$continent[df$country == "Taiwan Province of China"] <- "Asia"
df$continent[df$country == "United States"] <- "Americas"

# %%
# transformar coluna de ano para inteiro
df$year <- as.integer(df$year)

df$year %>% unique()
# Out:
#  [1] 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2007 2006 2005

# %%
# criar dataset apenas para o ano mais recente
df_2017 <- df %>% 
  filter(year == max(year))

# %% [markdown]
# ### geoms

# %%
# geom_bar() e geom_col()
# Tarefa: Criando um gráfico mostrando a média do score de felidade por continente
df_2017 %>% 
  group_by(continent) %>% 
  summarise(life_ladder = mean(life_ladder)) %>% 
  ggplot(aes(x = continent, y = life_ladder)) +
  geom_col()
# Out:
# plot without title

# %%
# geom_point()
df_2017 %>% 
  filter(!is.na(log_gdp_per_capita), !is.na(healthy_life_expectancy_at_birth)) %>% 
  ggplot(aes(x = log_gdp_per_capita, y = healthy_life_expectancy_at_birth)) +
  geom_point()
# Out:
# plot without title

# %%
# geom_line()
df %>% 
  filter(country == 'Brazil') %>% 
  ggplot(aes(x = year, y = life_ladder)) +
  geom_line()
# Out:
# plot without title

# %%
# geom_histogram()
df_2017 %>% 
  ggplot(aes(x = life_ladder)) +
  geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
# geom_text()
df_2017 %>%
  ggplot(aes(x = log_gdp_per_capita, y = healthy_life_expectancy_at_birth)) +
  geom_point() +
  geom_text(aes(label = country))
# Out:
# Warning message:
# "Removed 7 rows containing missing values (geom_point)."Warning message:
# "Removed 7 rows containing missing values (geom_text)."
# plot without title

# %%
# geom_hline() e geom_vline()
df_2017 %>% 
  ggplot(aes(x = log_gdp_per_capita, y = healthy_life_expectancy_at_birth)) +
  geom_point() +
  geom_vline(aes(xintercept = mean(df_2017$log_gdp_per_capita, na.rm = TRUE))) +
  geom_hline(aes(yintercept = mean(df_2017$healthy_life_expectancy_at_birth, na.rm = TRUE)))
# Out:
# Warning message:
# "Removed 7 rows containing missing values (geom_point)."
# plot without title

# %% [markdown]
# ### aes

# %%
# Mudando a propriedade color dos pontos para um valor específico: marrom
df_2017  %>% 
    ggplot(aes(x = log_gdp_per_capita,
              y = healthy_life_expectancy_at_birth)) +
    geom_point(color = "brown")
# Out:
# Warning message:
# "Removed 7 rows containing missing values (geom_point)."
# plot without title

# %%
# cor para o continente do país
df_2017  %>% 
    ggplot(aes(x = log_gdp_per_capita,
              y = healthy_life_expectancy_at_birth)) +
    geom_point(aes(color = continent))
# Out:
# Warning message:
# "Removed 7 rows containing missing values (geom_point)."
# plot without title

# %%
# definindo o atributo dentro da função geral do gráfico
df_2017  %>% 
    ggplot(aes(x = log_gdp_per_capita,
              y = healthy_life_expectancy_at_birth,
              color = continent)) +
    geom_point()
# Out:
# Warning message:
# "Removed 7 rows containing missing values (geom_point)."
# plot without title

# %%
# adicionando o geom_smooth()
df_2017  %>% 
    ggplot(aes(x = log_gdp_per_capita,
              y = healthy_life_expectancy_at_birth)) +
    geom_point(aes(color = continent)) +
    # adicionando curva de tendência, sem margem de erro, usando o método
    # de regressão linear
    geom_smooth(method = "lm", se = FALSE)
# Out:
# Warning message:
# "Removed 7 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 7 rows containing missing values (geom_point)."
# plot without title

# %%
df_2017  %>% 
    ggplot(aes(x = log_gdp_per_capita,
              y = healthy_life_expectancy_at_birth,
              color = continent)) +
    geom_point() +
    # adicionando uma curva de tendência, sem margem de erro, usando o método
    # de regressão linear
    geom_smooth(method = "lm", se = FALSE)
# Out:
# Warning message:
# "Removed 7 rows containing non-finite values (stat_smooth)."Warning message:
# "Removed 7 rows containing missing values (geom_point)."
# plot without title

# %%
# Definindo mais de um geom ao mesmo tempo
df_2017  %>% 
    ggplot(aes(x = log_gdp_per_capita,
              y = healthy_life_expectancy_at_birth)) +
    # mapear cor ao continente
    geom_point(aes(color = continent,
                  # tamanho a confiança no governo
                  size = confidence_in_national_government),
                  # opacidade a um valor absoluto
                  alpha = 0.7)
# Out:
# Warning message:
# "Removed 19 rows containing missing values (geom_point)."
# plot without title
